# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%capture
# !pip install sentence_transformers

# %%
from sentence_transformers import SentenceTransformer, LoggingHandler, models, evaluation, losses
from torch.utils.data import DataLoader
from sentence_transformers.datasets import ParallelSentencesDataset
from datetime import datetime
import numpy as np
from sklearn.cluster import AgglomerativeClustering

# %%
saved_model_path = "/content/drive/MyDrive/Embeddings/make-multilingual-en-ne-2023-09-12_21-09-30`b"
model = SentenceTransformer(saved_model_path)

# %%
# Annotated Queries
f = open("/content/drive/MyDrive/SBert/annotedqueries.txt", "r")
queries = f.read().split("\n")
filtered_queries = []

for query in queries:
  query = query.replace("-", "").strip()
  filtered_queries.append(query)

print(filtered_queries)
# Out:
# ['portfolio not update', 'i could not open my share holder', 'sir ma uae ma xu malai demat and mero share account open garni xa yaha kati thauma bujheko xu but khi help vayana', '299 wala tireko ho paisa chai 360 ho ki kati ho kateko thiyo', 'i could not import my share.', 'why i cannt add ime life stock in my portfoli', 'i have import error', 'import bhayenaw meroshare bata', 'i have import issue', 'already exists with this number and email vancha', 'what is the difference between bull and shark features?', 'payment vaii sako tara enrolled vaxaina kina ho', 'how to delete porfolio', 'hello in my protfolio csv file is not impot', 'i am not able to import portfolio its showing error', "i'm unable to get otp while singup", 'cannot delete my portfolio stocks', "yes i have already download and after uploading file is sowing internal server error, i am facing this problem with my second portfolio as well. i can't refresh", "share can't add come error", 'i opened my mobil but not opend in my laptop', 'did not get any otp??', 'i creat id but unable to login', "mero share maa allotted 10 in ur app nothing... what's wrong in this...do you have any idea", 'i forget my password please', 'tapai haru ko app ma nadep laghubitta nai dekhaudaina ta', 'wht cant i use mega bargain option nin basket although i have taken subscription', 'the window where i should put my otp dissapearwd', 'yo 74 kitta mistake vayo  delete garna lako diyana', 'hello portfolio refresh issue', 'in sell history i already delet in hidcl stock, so how is fixed it?', 'portfolio import garnaw milk chainaw', 'ipo not showing of  sig3, ksly, cs30mf and rbbmf2', 'actually i entry in wrong so .. want to delete .', "why can't i export to excel from screener ???", "my subscription is not showed.....what's problem ??", 'i have entered wrong mobile no', 'web ta jhan company ko name nai dekhako xaen', 'i’m unable to upload cvs portfolio', 'getting error message while uploding cvs file in portfolio', 'getting error message while uploading cvs file', 'i am unable to attached my portfolio in the app', "i'm not being able to import my portfolio.", 'my portfolio is not imported', 'kasto app ho kam pareko bela error matra aauxa', 'dear sir madam portfolio ma rfm1 naamak company show hudaina kina hola', "mistakely i didn't put otp so my new account is not verified so please further information", 'i have a problem with the ideapreneur app course', 'i forget my password', 'forgot password?', 'the problem is what i subscribe jumbo combo course & want to watch in laptop', 'i have issue importing portfolio', 'ideapreneur app is working', "i can't access my ideapreneur app", 'maile mistakenly sip ma yo add gare xu i wanna remove this transaction kasari delete garnu sip ma delete garni option nai xaina raixa', '.cvs is not uploading', "i can't access ideapreneur app too", 'मेरो पोर्टफोलियोमा ओभरअल गेन र रियलाईज्ड गेन किन माईनसमा देखाउछ ?', 'i can not updated my portfolio', "mistakly i didn't put otp so my new account is not verified so please how to activate my account", "can't select csv file", "i'm not able to add my portfolio from mero share", 'not able to add portfolio', 'mero mah login vaye rako xaina', "it require otp but i don't have my mobile number because i have been in qatar", 'now i got the email with otp but can find a place to put in', 'i am in australia and i am having problem with payment method due to otp issue', 'course complete garda ni certificate ko pdf aaudaina ni k vako?', 'dear sir madam portfolio ma rfm2 naamak company show hudaina kina hola.', 'herdisakey taini complete  hunaaa mero ta kina horaa', 'i forgot email id used for login', 'plz help me to add boid & crn of my whole family members in this guru mantra.', 'maile mega bargain subscribe gareko thiyo hijo yo ahile samma open bhayana please heridinos na mobile number 9840365738', 'but website ma vayeko xaiana', 'why cant i upload my open mutual fund in my portfolio?', 'i cannot redem my certificate', 'hi, i can not ...

# %% [markdown]
# ## Encoding with self trained model

# %%
import scipy.spatial

corpus_embeddings = model.encode(filtered_queries)

# %%
# Query sentences:
queries = ['subscription cancel kasari garne?', 'portfolio app ma import garnai milena']
query_embeddings = model.encode(queries)

# Find the closest 5 sentences of the corpus for each query sentence based on cosine similarity
closest_n = 5
for query, query_embedding in zip(queries, query_embeddings):
    distances = scipy.spatial.distance.cdist([query_embedding], corpus_embeddings, "cosine")[0]

    results = zip(range(len(distances)), distances)
    results = sorted(results, key=lambda x: x[1])

    print("\n======================\n")
    print("Query:", query)
    print("\nTop 5 most similar sentences in corpus:\n")

    for idx, distance in results[0:closest_n]:
        print(filtered_queries[idx].strip(), "(Score: %.4f)" % (1-distance))
# Out:
# ======================
#
# Query: subscription cancel kasari garne?
#
# Top 5 most similar sentences in corpus:
#
# maile course lin kojeko sir mistake sark 1yr plan subscription vaye jasto ch yeslai cancel garer course ma change garnu  mildinw ? (Score: 0.7470)
# how can i delete my portfolio from gurumantra (Score: 0.6990)
# how to delete portfolio (Score: 0.6820)
# yo app upgrade garna lai payment garna lai aaru subidha xaian? (Score: 0.6791)
# how to delete sold stock on protfolio (Score: 0.6739)
#
# ======================
#
# Query: portfolio app ma import garnai milena
#
# Top 5 most similar sentences in corpus:
#
# how i can import my portfolio from mero share & tms (Score: 0.7940)
# how to import my portfolio from mero share (Score: 0.7894)
# portfolio import garnaw milk chainaw (Score: 0.7281)
# तपाईँ हरूको subscription lida k kasto facilities xa janna maan lagera sir (Score: 0.7126)
# trending garn garn yo technical analysis course matrai kiye hudain ra sir (Score: 0.6553)

# %% [markdown]
# ## Encoding with MiniLM-L6

# %%
embedder = SentenceTransformer('all-MiniLM-L6-v2')

corpus_embeddings_2 = embedder.encode(filtered_queries)
# Out:
# Downloading (…)e9125/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)7e55de9125/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)55de9125/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)125/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)e9125/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading (…)9125/train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading (…)7e55de9125/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)5de9125/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
# Query sentences:
queries = ['why my subscription still not activated', 'portfolio app ma import garnai milena']
query_embeddings_2 = embedder.encode(queries)

# Find the closest 3 sentences of the corpus for each query sentence based on cosine similarity
closest_n = 5
for query, query_embedding_2 in zip(queries, query_embeddings_2):
    distances = scipy.spatial.distance.cdist([query_embedding_2], corpus_embeddings_2, "cosine")[0]

    results = zip(range(len(distances)), distances)
    results = sorted(results, key=lambda x: x[1])

    print("\n======================\n")
    print("Query:", query)
    print("\nTop 5 most similar sentences in corpus:\n")

    for idx, distance in results[0:closest_n]:
        print(filtered_queries[idx].strip(), "(Score: %.4f)" % (1-distance))
# Out:
# ======================
#
# Query: why my subscription still not activated
#
# Top 5 most similar sentences in corpus:
#
# what happened my subscription is still not activated? (Score: 0.9410)
# my subscription is not showed.....what's problem ?? (Score: 0.8021)
# how can i get to know that i have got my subscription or not sir ?? (Score: 0.6325)
# even after subscription. i got the above error. (Score: 0.6313)
# how to activate my account (Score: 0.6016)
#
# ======================
#
# Query: portfolio app ma import garnai milena
#
# Top 5 most similar sentences in corpus:
#
# portfolio import garnaw paro (Score: 0.7245)
# i cannot import my portfolio in this app (Score: 0.6896)
# portfolio import (Score: 0.6566)
# portfolio import garda kati stock matrai available ho ? (Score: 0.6502)
# how to import me portfolio (Score: 0.6371)

# %% [markdown]
# ## Clustering

# %%
# Clustering

# Normalize the embeddings to unit length
corpus_embeddings_2 = corpus_embeddings_2 /  np.linalg.norm(corpus_embeddings_2, axis=1, keepdims=True)

# Perform kmean clustering
clustering_model = AgglomerativeClustering(n_clusters=None, distance_threshold=2) #, affinity='cosine', linkage='average', distance_threshold=0.4)
clustering_model.fit(corpus_embeddings_2)
cluster_assignment = clustering_model.labels_

clustered_sentences = {}
for sentence_id, cluster_id in enumerate(cluster_assignment):
    if cluster_id not in clustered_sentences:
        clustered_sentences[cluster_id] = []

    clustered_sentences[cluster_id].append(filtered_queries[sentence_id])

# %%
cluster_embeddings = []
for i, cluster in clustered_sentences.items():
    cluster_embeddings.append(embedder.encode(cluster))

# %%
clustered_sentences = dict(sorted(clustered_sentences.items()))
print(clustered_sentences)
# Out:
# {0: ['already exists with this number and email vancha', 'i opened my mobil but not opend in my laptop', "mero share maa allotted 10 in ur app nothing... what's wrong in this...do you have any idea", 'wht cant i use mega bargain option nin basket although i have taken subscription', 'i have entered wrong mobile no', 'the problem is what i subscribe jumbo combo course & want to watch in laptop', "it require otp but i don't have my mobile number because i have been in qatar", 'i can’t open this app', 'can you delete my account i want to do a subscription with conplete new', "it did't work", 'too slow app', 'invalid referral code vanxa ta', "hello sir/ madam, i am trying to buy your course but i couldn't sent  money through esewa", 'hello sir , i am living in foreign country and i want yearly subscription but i don’t have esewa and ips connection', 'facing problems sir', 'is it possible to transfer the subscription fee through himb mobile banking app?', 'why this app dont work', 'how i can reach to sip charts', 'sir i would like to reset my device', 'how to pay and how can i use these apps plz.i have not any idea.', 'can you please help me to make dmat account', 'how can we change mobile number and email?', 'not available free service like sharehub app?only free trial for few days?', 'is this paid app', 'how do i contact customer support?', 'is there anyone to help me?', 'not responding  purchases  transaction???', 'could you please help me?', 'how can i connect to customer suport', 'is there anyone who can guide me _', 'anyways thanks for the prompt reply, hope the bug gets fixed soon', 'i tried to contact many times in that given number but wasnot responded.', 'check this out, it’s going so issues with same your account in tiktok', 'please fix it. it would be better if we can update manaully by ourselves not uploading through mero share.', 'i paid the beginners package for one month through esewa. money is reduced from wallet but is not activated. whats the issue ?', 'your video is so informative for sip plan .  so i have  suggested  for your video to watch', 'slow ni ati slow xa yr daai app', 'thanks sir for response. basket features are very good category. thanks again sir.', 'i haved tried many time while market is open it dosenot work', 'not fixed yet, paid account mai esto error ali vaena!', 'and some transaction i can not even delete, it says the transaction is only partially sold', 'man you guys have to work a lot on this app it says to update all the time but any any special update'], 1: ['i have import error', 'i have import issue', 'hello in my protfolio csv file is not impot', "why can't i export to excel from screener ???", "can't select csv file", 'how to delete the imported files so that i can import again?', 'how to export excel in mobile', 'is it possible in mobile? suppose i installed the excel how i fill all the stock and their pe ratio , eps, etc.', 'how to import excel sheet on money mitra web', 'hello can i have a copy to this sheet? or website link through which i can access it?', 'and how do i copy this?', 'how can i get class notes'], 2: ['refer code doesn’t work how can solve', 'how to get referral code', 'referalll', 'where is my referral code', 'how to find referral code', 'referral code plz', 'referral code needed', 'what is my referral code ??', 'is it possible to get some discount or please provide me referral code so i can get 10% off', 'referall code', 'is there any coupon code or discount available?', 'referall', 'how i can generate won referral code to provide other persons', 'can i get referrel code for discount?', 'hou to found referral code sir', 'how we can get referrals code ?', 'pls can i have referral code', 'pls can u provide referral code'], 3: ['portfolio not update', 'i am not able to import portfolio its showing error', "yes i have already download and after uploading file is sowing internal server error, i am facing this problem with my second portfolio as well. i can't refresh", ' ...

# %% [markdown]
# ## Encoding and Clustering

# %%
# Query sentences:
queries = ['i have not got any otp yet', 'portfolio app ma import garnai milena']
query_embeddings_2 = embedder.encode(queries)

# Find the closest 10 sentences of the corpus for each query sentence based on cosine similarity
closest_n = 10

def most_frequent(List):
    unique, counts = np.unique(List, return_counts=True)
    print(unique, counts)
    index = np.argmax(counts)
    return unique[index]

for query, query_embedding_2 in zip(queries, query_embeddings_2):
    cluster_number = []
    distances = scipy.spatial.distance.cdist([query_embedding_2], corpus_embeddings_2, "cosine")[0]

    results = zip(range(len(distances)), distances)
    results = sorted(results, key=lambda x: x[1])

    print("\n======================\n")
    print("Query:", query)
    print("\nMost Similar Cluster:\n")

    # Finds the 10 closest sentences for each corpus
    for idx, distance in results[0:closest_n]:
        matched_result = filtered_queries[idx]
        for i, cluster in clustered_sentences.items():
          if matched_result in cluster:
            cluster_number.append(i)
            break

    # Determines the most frequently occuring cluster number
    most_frequent_cluster = most_frequent(cluster_number)
    print(f"Cluster {most_frequent_cluster + 1}")
    print(clustered_sentences[most_frequent_cluster])
# Out:
# ======================
#
# Query: i have not got any otp yet
#
# Most Similar Cluster:
#
# [ 0 15 20 24] [1 1 1 7]
# Cluster 25
# ["i'm unable to get otp while singup", 'did not get any otp??', 'the window where i should put my otp dissapearwd', "mistakely i didn't put otp so my new account is not verified so please further information", "mistakly i didn't put otp so my new account is not verified so please how to activate my account", 'now i got the email with otp but can find a place to put in', 'did not get any otp']
#
# ======================
#
# Query: portfolio app ma import garnai milena
#
# Most Similar Cluster:
#
# [ 3 10 17] [7 1 2]
# Cluster 4
# ['portfolio not update', 'i am not able to import portfolio its showing error', "yes i have already download and after uploading file is sowing internal server error, i am facing this problem with my second portfolio as well. i can't refresh", 'hello portfolio refresh issue', 'i am unable to attached my portfolio in the app', "i'm not being able to import my portfolio.", 'my portfolio is not imported', 'i have issue importing portfolio', 'i can not updated my portfolio', 'not able to add portfolio', 'hi, i can not updated my portfolio , is sowing always 500 internal server error', 'portfolio import not worked?', 'why …500 internal server error is popping out while importing portfolio', 'why ...500 internal server error is popping out while importing portfolio', 'i ve been trying to add my portfolio and i can verify my import', 'why i can not import my portfolio ?', 'i cannot import my portfolio in this app', 'error while importing portfolio', 'portfolio import', 'how to import portfolio', 'how to import me portfolio']

# %%
for i, cluster in clustered_sentences.items():
    print("Cluster ", i+1)
    print(cluster)
    print("")
# Out:
# Cluster  1
# ['already exists with this number and email vancha', 'i opened my mobil but not opend in my laptop', "mero share maa allotted 10 in ur app nothing... what's wrong in this...do you have any idea", 'wht cant i use mega bargain option nin basket although i have taken subscription', 'i have entered wrong mobile no', 'the problem is what i subscribe jumbo combo course & want to watch in laptop', "it require otp but i don't have my mobile number because i have been in qatar", 'i can’t open this app', 'can you delete my account i want to do a subscription with conplete new', "it did't work", 'too slow app', 'invalid referral code vanxa ta', "hello sir/ madam, i am trying to buy your course but i couldn't sent  money through esewa", 'hello sir , i am living in foreign country and i want yearly subscription but i don’t have esewa and ips connection', 'facing problems sir', 'is it possible to transfer the subscription fee through himb mobile banking app?', 'why this app dont work', 'how i can reach to sip charts', 'sir i would like to reset my device', 'how to pay and how can i use these apps plz.i have not any idea.', 'can you please help me to make dmat account', 'how can we change mobile number and email?', 'not available free service like sharehub app?only free trial for few days?', 'is this paid app', 'how do i contact customer support?', 'is there anyone to help me?', 'not responding  purchases  transaction???', 'could you please help me?', 'how can i connect to customer suport', 'is there anyone who can guide me _', 'anyways thanks for the prompt reply, hope the bug gets fixed soon', 'i tried to contact many times in that given number but wasnot responded.', 'check this out, it’s going so issues with same your account in tiktok', 'please fix it. it would be better if we can update manaully by ourselves not uploading through mero share.', 'i paid the beginners package for one month through esewa. money is reduced from wallet but is not activated. whats the issue ?', 'your video is so informative for sip plan .  so i have  suggested  for your video to watch', 'slow ni ati slow xa yr daai app', 'thanks sir for response. basket features are very good category. thanks again sir.', 'i haved tried many time while market is open it dosenot work', 'not fixed yet, paid account mai esto error ali vaena!', 'and some transaction i can not even delete, it says the transaction is only partially sold', 'man you guys have to work a lot on this app it says to update all the time but any any special update']
#
# Cluster  2
# ['i have import error', 'i have import issue', 'hello in my protfolio csv file is not impot', "why can't i export to excel from screener ???", "can't select csv file", 'how to delete the imported files so that i can import again?', 'how to export excel in mobile', 'is it possible in mobile? suppose i installed the excel how i fill all the stock and their pe ratio , eps, etc.', 'how to import excel sheet on money mitra web', 'hello can i have a copy to this sheet? or website link through which i can access it?', 'and how do i copy this?', 'how can i get class notes']
#
# Cluster  3
# ['refer code doesn’t work how can solve', 'how to get referral code', 'referalll', 'where is my referral code', 'how to find referral code', 'referral code plz', 'referral code needed', 'what is my referral code ??', 'is it possible to get some discount or please provide me referral code so i can get 10% off', 'referall code', 'is there any coupon code or discount available?', 'referall', 'how i can generate won referral code to provide other persons', 'can i get referrel code for discount?', 'hou to found referral code sir', 'how we can get referrals code ?', 'pls can i have referral code', 'pls can u provide referral code']
#
# Cluster  4
# ['portfolio not update', 'i am not able to import portfolio its showing error', "yes i have already download and after uploading file is sowing internal server error, i am facing this problem with my second portfolio as well. i can't refresh", 'hello portfolio refresh issue', 'i am unable to attached my portfolio in the app', "i'm not being able to import my portfolio.", 'my portfolio is not imported', 'i have issue importing portfolio', 'i can not updated my portfolio', 'not able to add portfolio', 'hi, i can not updated my portfolio , is sowing always 500 internal server error', 'portfolio import not worked?', 'why …500 internal server error is popping out while importing portfolio', 'why ...500 internal server error is popping out while importing portfolio', 'i ve been trying to add my portfolio and i can verify my import', 'why i can not import my portfolio ?', 'i cannot import my portfolio in this app', 'error while importing portfolio', 'portfolio import', 'how to import portfolio', 'how to import me portfolio']
#
# Cluster  15
# ['hlo sir i have one question', 'hlow', 'hlo sir', 'hlo', 'hlw sir nameste', 'hlw', 'helo', 'Hlo', 'hlw sir', 'helo?']
#
# Cluster  16
# ["my subscription is not showed.....what's problem ??", 'even after subscription. i got the above error.', 'how to subscribe for a month? when i click month it goes to year and vice versa.', 'i have subscribed the bull subcription for a month but still i can’t access it .', 'not getting what we want, after taking the subscription really hits hard.', 'how can payment for subscription?', 'what happened my subscription is still not activated?', 'how to subscribe', 'how to subscribe? price of subscription', 'what is the price of subscription', 'suppose i finish one time i want to see next time also available or next time also need subscribe', 'how much for total subscription', 'tell me about subscription package (130) or (1010)', 'how can i get to know that i have got my subscription or not sir ??', 'how can it subscribe/?', 'What kind of subscriptions are there?']
#
# Cluster  17
# ['Question', 'what you do', 'what service you do', 'how are you?', 'what is your name?', 'what is your name', '', '', 'are you there?', 'good night', 'have a nice day!', 'good evening']
#
# Cluster  18
# ['why i cannt add ime life stock in my portfoli', 'portfolio import garnaw milk chainaw', 'why cant i upload my open mutual fund in my portfolio?', 'even when i upload from mero share other share dekhaucha but yo open ended mutual fund ko chai khi upload hudaina', 'yo add portfolio ma open ended mutual fund kina dekhaudaina?', "how to make portfolio in money mitra i can try but didn't ?", 'portfolio import garnaw paro', 'how to invest in gorumantra', 'portfolio import garda kati stock matrai available ho ?', 'यो money mitra app मा आफ्नो portfolio कसरि add गर्नुपर्ने हो', 'open ended mutual fund lai afno portfolio ma add kasari garne hola?', '"mutual fund and sip" vanni duita topic xa app ma (euta 45min ra arko 20min) but website ma 20min wala matra xa', "kindly update the balance sheets, annual reports and income statements to the most recent ones for every stock. it doesn't make sense to buy the package and not getting the benefits we are wanting from it.", "i add my all stock in protofolio.but after 12 weeks it was  deleated itself. manage this error in this app.so i don't need to add every time"]
#
# Cluster  19
# ['i forget my password please', 'i forget my password', 'forgot password?', 'i forgot email id used for login', 'actully i forgot my password', 'hello i forgot that which email id was used for login', 'how to set password', 'wher can i find the forgot password option']
#
# Cluster  20
# ['could you explane me what is undervalued and overvalued?', 'hi could you explane me what is undervalued and overvalued?', 'can i get the data of divident capity of companies?', 'i want to know my ipod result', 'how abt chcl?', 'what does 4680.69% mean?', 'in money mitra where we can see locking period of a company', 'plz help me', 'tq', 'uic and ail is already merged and your report is showing individual report', 'sebon commission calculation is incorrect', 'or could you add an option to overwrite the calculated commission?', 'lbl growth rate was 0.00% today it is showing the wrong figure']
#
# Cluster  21
# ['i am in australia and i am having problem with payment method due to otp issue', 'there is some issued on your payment system', 'there is some issued on payment connect ips', 'hello just started any possibility to pay from visa card? because ia m abroad', 'is there an option paying from visa card', 'how much do i need to pay in total ??', 'what does paypal mean ??', 'payment method', 'how i can pay you..?']
#
# Cluster  22
# ['i could not open my share holder', 'i could not import my share.', "share can't add come error", 'how i create shareholder ?', 'can we buy a share today and sell it tomorrow', 'should i sell joshi shares?', 'how can i buy shares', 'i just want to buy shares', 'if we are already alloted in local share, can we reapply in public issue?', 'if i buy today on 28 sharwan when will it expire', 'in how many days share is there in our demate account', 'how to choose purchase company']
#
# Cluster  23
# ["i'm not able to add my portfolio from mero share", 'i wanted to import portfolio from mero share but unable to do so', 'how can upload portfolio frm mero share', 'how to import my portfolio from mero share?', 'how to import shares from mero share?', 'how to import my portfolio from mero share', 'how i can import my portfolio from mero share & tms']
#
# Cluster  24
# ['yes vayo  thank you', 'ok sir thank you vayo aru', 'vayo sir ..  thankyou 🙏', 'yes vayo  thanks', 'vayo thanks']
#
# Cluster  25
# ["i'm unable to get otp while singup", 'did not get any otp??', 'the window where i should put my otp dissapearwd', "mistakely i didn't put otp so my new account is not verified so please further information", "mistakly i didn't put otp so my new account is not verified so please how to activate my account", 'now i got the email with otp but can find a place to put in', 'did not get any otp']
#
# Cluster  26
# ['i creat id but unable to login', 'i cannot redem my certificate', 'enrolled ma data not found bhanxa tw', 'how to access to vridhi', 'how to activate account', 'how to login sar', 'how to active my account showing this account is inactive', 'how to activate my account', 'how to activate acc', 'i am not able to create account', 'it does not show that i am enrolled']
#
# Cluster  27
# ['i’m interested in tech analysis.you you conduct classes or tutorial currently.?', 'does it contain financial and technical analysis courses?', 'do we have a training session? on how do we use these tools efficiently ?', 'for the beginner do we need to take all the classes or just basic is ok ?', 'for the beginner which plan is suitable?', 'how can we use this application?', "i purchased the course of fundamental and technical analysis. in that video you told about excel but i don't have laptop or computer so, what can do for that?", 'how to use the tools effectively.']
#
# Cluster  28
# ['ok thanks  for reply my msg', 'ok thank you sir', 'ok thanks', 'ok thank u', 'this is okay thank u sir', 'ok, thank you so much sir', 'ok thanks a lot', 'ok sir thanku so much', 'ok thank you', 'ok. thanks for']
#
# Cluster  29
# ['where is paper trading?', 'how can i use virtual demo trading?', 'which broker should i choose if i am in butwal', 'how can i use demo trading ??', 'i want to open a broker account', 'i would like to invest and learn from ground level but how', 'sir paper trading k ho', 'how to use demo trading?', 'i m interested to learn about secondary market', 'i want to learn trading and investing']
#
# Cluster  30
# ['what are the fees structure?', 'fee structures?', 'what is the fee structures?', 'may i know the fee structures?']
#
# Cluster  31
# ['ipo not showing of  sig3, ksly, cs30mf and rbbmf2', 'i saw some ipo results are not appearing correctly in your apps', 'no way that we are able to apply ipo from 5 account all at once as it is to check ipo results?  willing to pay a premium for it', 'how to use watch list of ipo', 'can you tell me about upcoming ipo']
#
# Cluster  32
# ['hi  sir', 'hello sir/madam', 'hello sir', 'hello sir 👍', 'sir', 'ho sir', 'hello sir 🙏', 'hallo sir']
#
# Cluster  33
# ['i’m unable to upload cvs portfolio', 'getting error message while uploding cvs file in portfolio', 'getting error message while uploading cvs file', '.cvs is not uploading', 'getting error message while uploading cvs file in portfolio']
#
# Cluster  34
# ['hey there,', 'hello any response', 'hello good moring', 'hello?', 'hello there ?', 'hello there', 'hi', 'hello', 'hey there', 'hello brother/sister', 'hey', 'hello.', 'hi there', 'hello !', 'hello\\', 'hello good morning', 'Hello is there anyone', 'Hello, is there anyone I can talk to?', 'Hi is anyone there', 'Hello there...', 'hi 👋']
#
# Cluster  35
# ['hajur haru training ne dinu hunxa', 'queries haru vayo vane shodhan milxa ki nai..', 'sir courses haru japan bata purchase garna milxa ni mildaina?', 'physical class chai hunna?', 'jumbo cumbo course kasto hola hajur? im also intrested on treading', 'physical class xaina sanjok dai??? tech and funda ko', 'hello sir namaste.  fundamentals and technical course subscription lieko open vayen kin hola  ?', 'sir maile combo course lageko, harne kata bata thaa nai vayana', 'sir, maile jumbo combo course lageko rahexu,. kattiko helpfull hunxa hola?', 'money pay garepaxi courses haru download garna pauxa?', 'physicals class khaile bata suru hunxa??', 'cost kati parxa online class ko??', 'online class kasle dinu hunxa??', 'hajur ko office kata xa??', 'hajur harulai contact garne kunai number?', 'hello sir namste  maile jumbo course ko subscription lieko xu .. yesko validate time kati hunxh ?', 'aba mero barema maile sabai kura vane aba hajur le bhani dinu hos please maile kun hajur haru ko online course gare thik hola ?', 'is there physical training class as well', 'hajur ko office kata ho', 'hajur sir', 'thank u for the course aba arkoni lincu chaddai', 'namaste hajur', 'course liyara ma ta fasyani hajur haru solution dinu huda raina6...']
#
# Cluster  36
# ['thanks for the info', 'thank you for your quick response and support.', 'ohh... thank you for your information..', 'thanks for information', 'thank you for information', 'ok thank you for information']
#
# Cluster  37
# ['i have recently purchased the subscription of money mitra from app store my account is not activated yet.', 'what is money mitra', 'how can i use money mitra', 'does money mitra provide ai signals?', 'namaste sir. i got a chance to see moneymitra.  generally i found all features also basket. one question, could i get stocks buy, hold and sell signal generated by ai.? is this features available? thanks.', 'i want open .money mitra', 'how can i find the newsletter section of money mitra?', 'wow i like the money mitra app i can buy money mitra share or no?', 'i want to seen all under money mitra it means whole subscribe price????', 'what is money mitra?', 'what are the major goals of money mitra?', 'yes but i am using nepse alpha ,sharesansar and trying to switch to money mitra the performance is worst only for moneymitra', 'trying out money mitra, subscription ali mahango lagyo', 'hello money mitra i am shark user of money mitra app. i loved it and been a great help for me to choose stocks for portfolio management.']
#
# Cluster  38
# ['how to delete porfolio', 'in sell history i already delet in hidcl stock, so how is fixed it?', 'actually i entry in wrong so .. want to delete .', 'maile mistakenly sip ma yo add gare xu i wanna remove this transaction kasari delete garnu sip ma delete garni option nai xaina raixa', "yaa i delete in sell history but did't work still .. i send in photo via messenger", 'i want a delete in hidcl stock but did not delete so need a help for delete .', 'how do i delete all at once??', 'delete nai hunna ta transaction']
#
# Cluster  39
# ['your chart issue when you gonna fix', 'is there any option in chart dark mode?', 'where can i get chart', 'the chart doesnt well work in safari', 'your 1 min chart is also wrong see where market closed yesterday in 1 min and where it opened today you are showing huge gap which is not the case also green candles on other platforms are shown as red in your chart', 'why you guys have slowest 1 min chart other providers provide 1 min within 1015 seccs and you guys are like 2 min slower than live market', 'you chart needs serious updates and verification']
#
# Cluster  40
# ['मेरो पोर्टफोलियोमा ओभरअल गेन र रियलाईज्ड गेन किन माईनसमा देखाउछ ?', 'buy गरेको खोलेन सर', 'धन्यवाद', 'प्रत्येक्षरुपमा क्लास  हुने हो?', 'कुन शेयर कुन कंमपनि काे कहिले किन्ने कहिले बेच्ने भन्ने जानकारि कसरि लिने पाउने', 'मैले महिनाको ३००० को दर्ले share market मा invest गर्नि भनिको यउटा राम्रो stock recommended गर्दिनुहोस न।', 'अब technical analysis को advance course कहिले आउँछ ?', 'सर नमस्ते', 'धन्यवाद । मैले भर्खरै तपाईंहरुको app चलाइरहेको छु त्यसैले अनविग्य भएर यश बारेमा सोधेको हुँ । धेरै खुसि लाग्यो एउटै app मा धेरै भन्दा धेरै जानकारि दिनु भएको मा । 💕🙏🇳🇵🇳🇵🇳🇵', 'नमस्कार हजुर 🙏 यो मनि मित्र म साउदि बाट हेर्दैछु एकदमै राम्रो लाग्यो । अझ राम्रो गर्दै जानुस शुभकामना 💐💐💐']
#
# Cluster  41
# ['hello i am beginner and i recently took subscription of 299 but i am not getting any kind of courses', 'i have enrolled in one of your courses through mobile app however cannot access the same through web', 'i would like to purchase course. how can i do it ?', 'can i see course in website', 'how much this all of courses? for a month.', 'which course will be fruitful for me??', 'how to enroll course..?', 'i want to take the courses too does it includes in the subscription or do i need to make the additional payments ?', 'sir i have one question suppose if i buy combo course of share market fundamental and technical skills learning course then shall i get money mitra subscription also on it free or i will have to buy the subscription also separately', 'course are available in online once i suscribe i can see any time i means any days limit to', 'when digital marketing course will start', 'how long the course will be', 'is subscription is mandotary to taking a courses?']
#
# Cluster  42
# ['i have a problem with the ideapreneur app course', 'ideapreneur app is working', "i can't access my ideapreneur app", "i can't access ideapreneur app too", 'Why is ideapreneur app not working', 'ideapreneur course']
#
# Cluster  43
# ['stock basket khuldaina ta', 'hello sir maile kehi samaya agadi subscribstion liyako thiya sir mero ma basket ma vayaka stocks haru show hudaina kina hola', 'trading ko lagi kun stock chha sir  stock basket ma', 'ani sir gurumantras  stock basket  vitra vako cchuta chuttai pay garnu pardaina ni', 'sir sector wise stock basket vaya ajhai easy hune thiyo sir', 'stock basket ma limited stock ko paunu paryo ni sir']
#
# Cluster  44
# ['cannot delete my portfolio stocks', 'i cant delete my portfolio stock which i have already sold it.', 'i want to delete my portfolio how can i delete', 'i want to delete my portfolio , how can i delete ?', 'how to delete sold stock on protfolio', 'how can i remove stock from my portfolio', 'how to delete portfolio', 'how to remove portfolio?', 'how can i delete my portfolio from gurumantra', 'how to reset my portfolio?']
#
# Cluster  45
# ['thank u for nice response 🙏🙏', 'thank you soo much', 'thank u so much', 'thank you🙏', 'thank you it workedd😁', 'thank you so much for reply 🙂', 'thanks a lot 🙏', 'thank you 🙏', 'thank you so much', 'sure i will, thank you for your reply 🙏', 'thanks a lot', 'thank you 😊']
